# %%
from analyzebenchmark import AnalyzePyZXpass

# %%
app = AnalyzePyZXpass("now_dict_pickles/rb/2019-08-15T09:16:12.226399.p")
print(app.get_mean_depth())
app.plot_depth()
app.plot_size()
app.plot_cx_and_cz()
app.plot_percents()
# Out:
# [11.992805755395683, 8.906474820143885, 6.597122302158273, 7.179856115107913]
# <module 'matplotlib.pyplot' from '/anaconda3/envs/QiskitDevenv/lib/python3.7/site-packages/matplotlib/pyplot.py'>
