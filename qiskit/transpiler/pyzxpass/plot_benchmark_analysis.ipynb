# %%
from analyzebenchmark import AnalyzePyZXpass

# %%
app = AnalyzePyZXpass("now_dict_pickles/rb/2019-09-02T08:04:59.305005.p")
print(app.get_mean_depth())
app.plot_depth()
app.plot_size()
app.plot_cx_and_cz()
app.plot_percents()
# Out:
# [13.66, 12.277, 7.755, 9.492]
# <module 'matplotlib.pyplot' from '/home/lia/anaconda3/envs/QCDevEnv/lib/python3.7/site-packages/matplotlib/pyplot.py'>

# %%
print(app.__dict__)
# Out:
# {'_AnalyzePyZXpass__dict': {'time': '2019-09-02T08:04:59.305005', 'benchmark': 'rb', 'size': array([[24., 22., 22., ..., 26., 18., 18.],
#        [19., 16., 10., ..., 19., 16., 23.],
#        [14., 12., 12., ..., 14., 10., 10.],
#        [13., 11.,  8., ..., 16., 10., 21.]]), 'depth': array([[17., 15., 13., ..., 17., 11., 11.],
#        [15., 10.,  8., ..., 15., 11., 18.],
#        [ 9.,  7.,  7., ...,  9.,  7.,  7.],
#        [ 9.,  7.,  6., ..., 12.,  7., 15.]]), 'c count': array([[4., 2., 2., ..., 4., 2., 4.],
#        [4., 2., 2., ..., 6., 2., 9.],
#        [4., 2., 2., ..., 4., 2., 4.],
#        [4., 2., 2., ..., 6., 2., 9.]])}, '_AnalyzePyZXpass__mean_size': [20.018, 16.117, 11.694, 12.655], '_AnalyzePyZXpass__mean_depth': [13.66, 12.277, 7.755, 9.492], '_AnalyzePyZXpass__mean_c': [2.958, 4.778, 2.958, 4.664]}

# %%
print(len(app.get_dict()['size'][0]))
# Out:
# 1000

# %%
now_dict = app.get_dict()
depth_3_2 = [now_dict['depth'][3][j] / now_dict['depth'][2][j] for j in range(len(now_dict['depth'][0]))]
size_3_2 = [now_dict['size'][3][j] / now_dict['size'][2][j] for j in range(len(now_dict['size'][0]))]
s0 = len([i for i in size_3_2 if i < 1]) / len(size_3_2)
d0 = len([i for i in depth_3_2 if i < 1]) / len(depth_3_2)
s1 = len([i for i in size_3_2 if i == 1]) / len(size_3_2)
d1 = len([i for i in depth_3_2 if i == 1]) / len(depth_3_2)
print(d0, d0+d1)
print(s0, s0+s1)
# Out:
# 0.15 0.494
# 0.29 0.486

# %%
print(app.get_mean_size())
# Out:
# [20.018, 16.117, 11.694, 12.655]
